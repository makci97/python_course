# %% [markdown]
# # Задание по многопоточности:
#
# Вам необходимо проанализировать википедию на предмет того, какие слова в каждой из частей речи встречаются чаще. Вы хотите реализовать это в несколько потоков.
#
# Запросы к википедии можно осуществлять с помощью библиотеки wikipedia. Для морфологического анализа используйте библиотеку pymorphy2. Чтобы разбить текст на слова можете воспользоваться функцией word_tokenize из библиотеки nltk.
#
# Класс должен иметь функции, приведенные ниже (но может иметь и другие на ваше усмотрение).

# %%
def bool_check(b):
    b[0] = True

# %%
b = [False]
bool_check(b)
print(b)
# Out:
# [True]

# %% [markdown]
# ### Часть 1
#
# <b>Многопоточной реализация</b>
#
# Задачи делятся на три типа:
# <ul>
# <li><i>Получение данных</i>:
# <ol>
# <li>Получение заголовков для страниц википедии - запускает по max_threads функций, которые асинхронно получают заголовки страниц.</li>
# <li>Получение конкретных страниц - ждем, пока не появятся новые заголовки, которые не обработаны.
# Когда появились - начинаем запрашивать в max_threads функциях конкретные страницы по заголовкам.</li>
# </ol>
# </li>
# <li><i>Обработка данных</i>:
# <ol>
# <li>Ждем, пока не появятся новые необработанные страницы. Когда появляются, запускаем по max_threads функций для морфологического анализа слов.</li>
# <li>Ждем пока не появились обработанные слова. Как только появляется новое слово, сразу же обновляем _stats.</li>
# </ol>
# </li>
# <li><i>Сохранение данных</i>:
# <ol>
#         Раз в store_every обработанных слов вызывается асинхронно функция dump, которая сохраняет _stats.
# </ol>
# </li>
# </ul>
# <b>P. S.</b>
#
# Комментарии специально запутанные, чтобы вы сами придумали архитектуру вызова потоков. Не бойтесь использовать Queue и daemon=True. Запрещается использовать threading.Lock / threading.RLock или другие блокировки.

# %%
from collections import defaultdict, Counter
from queue import Queue

import numpy as np
import threading
import json
import wikipedia
import nltk
import pymorphy2

# %% [markdown]
# wikipedia.languages()

# %% [markdown]
# wikipedia.set_lang('ru')

# %% [markdown]
# title = wikipedia.random(pages=1)

# %% [markdown]
# print(title)

# %% [markdown]
# page = wikipedia.page(title)
#
# page.content

# %% [markdown]
# text = page.content
# words = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]

# %% [markdown]
# words[:8]

# %% [markdown]
# morph = pymorphy2.MorphAnalyzer()
#
# p = morph.parse(words[0])[0]
# p.tag.POS

# %% [markdown]
# type(morph.parse(words[6])[0].tag.POS)

# %% [markdown]
# np.array(wikipedia.random(pages=1)).reshape((-1))

# %% [markdown]
# for title in np.array(wikipedia.random(pages=2)).reshape((-1)):
#     print(title)

# %%
class WikiReader(object):
    """
    Класс для работы с википедией.
    Собирает статисткику по словам каждой части речи в статьях википедии.

    Parameters
    ----------
    morphs: list
        Части речи, которые хотим исследовать. Слова другой части речи не включаются в статистику.
    
    page_per_req: int
        Количество случайных названий страниц, запрашиваемых за один раз у википедии.
    
    max_threads: int
        Количество потоков, запускаемых другим потоком демоном (можно не использовать, если получится).
    
    max_words: int
        Количество слов для обработки.
    
    store_every: int
        Как часто сохранять данные на диск. Каждые store_every слов вызывается функция dump.
    
    store_path: str
        Куда сохранять данные.
    
    Attributes
    ----------
    _stats: <your code here>
        Структура данных (возможно встроенная), позволяющая хранить для каждой части речи список слов с их количеством.
        Необходимо, чтобы получение (изменение) статистики (текущего количества) для каждой пары
        <часть речи, слово> происходило за O(1).
            
    """
    def __init__(self,
                 morphs=[],
                 page_per_req=4,
                 max_threads_per_daemon=8,
                 max_words=10000,
                 store_every=1000,
                 store_path=""):
        self._stats = defaultdict(Counter)
        self.morphs = morphs
        self._stats.update({m: Counter() for m in morphs})
        self.processed_words = 0
        self.dump_count = 0
        self.max_words = max_words
        self.store_every = store_every
        self.store_path = store_path
        self.page_per_req = page_per_req
        self.max_threads_per_daemon = max_threads_per_daemon
        self.run_flags = {}
    
    def run(self):
        wikipedia.set_lang('ru')
        
        titles_q = Queue()
        pages_q = Queue()
        self.run_flags = {
            'title_daemon': True,
            'page_daemon': True,
            'processor_daemon': True,
        }
        
        titles_adder_daemon = threading.Thread(
            target=self.titles_adder_daemon, args=(titles_q,), daemon=True
        )
        titles_adder_daemon.start()

        pages_adder_daemon = threading.Thread(
            target=self.pages_adder_daemon, args=(titles_q, pages_q), daemon=True
        )
        pages_adder_daemon.start()

        processors_adder_daemon = threading.Thread(
            target=self.processors_adder_daemon, args=(pages_q,), daemon=True
        )
        processors_adder_daemon.start()
        
        while self.processed_words < self.max_words:
            pass
        
        self.run_flags = {
            'title_daemon': False,
            'page_daemon': False,
            'processor_daemon': False,
        }
            
        
    def dump(self, path=None):
        self.dump_count += 1
        cur_stats = self._stats.copy()
        with open(path, 'w', encoding="utf-8") as file:
            # writing
            json.dump(cur_stats, file, indent=4, ensure_ascii=False)
    
    def load(self, path=None):
        with open(path, 'r') as file:
            self._stats = json.load(file)
            
    def titles_adder_daemon(self, titles_q):
        while True:
            if self.run_flags.get('title_daemon', False):
                threads = [threading.Thread(target=self.thread_titles_adder, args=(titles_q,))
                           for _ in range(self.max_threads_per_daemon)]
                WikiReader.do_work(threads)
                
    def thread_titles_adder(self, titles_q):
#         while True:
        for title in np.array(wikipedia.random(pages=self.page_per_req)).reshape((-1)):
            titles_q.put(title)
                
            
    def pages_adder_daemon(self, titles_q, pages_q):
        while True:
            if self.run_flags.get('page_daemon', False):
                threads = [threading.Thread(target=self.thread_pages_adder, args=(titles_q, pages_q))
                           for _ in range(self.max_threads_per_daemon)]
                WikiReader.do_work(threads)
        
    def thread_pages_adder(self, titles_q, pages_q):
#         while True:
        title = titles_q.get()
        try:
            pages_q.put(wikipedia.page(title).content)
        except wikipedia.exceptions.DisambiguationError:
            pass
        titles_q.task_done()
                
            
    def processors_adder_daemon(self, pages_q):
        while True:
            if self.run_flags.get('processor_daemon', False):
                threads = [threading.Thread(target=self.thread_page_processing, args=(pages_q,))
                           for _ in range(self.max_threads_per_daemon)]
                WikiReader.do_work(threads)
                
    def thread_page_processing(self, pages_q):
        morph = pymorphy2.MorphAnalyzer()
#         while True:
        page = pages_q.get()
        words = [word for sent in nltk.sent_tokenize(page) for word in nltk.word_tokenize(sent)]
        for word in words:
            self.word_processing(word, morph)
#         list(map(lambda word: self.word_processing(word, morph), words))
        pages_q.task_done()

    def word_processing(self, word, morph):
        p = morph.parse(word)[0].tag.POS
        if p in self.morphs:
            self._stats[p][word] += 1
            self.processed_words += 1
            if self.processed_words >= self.store_every * (self.dump_count + 1):
                self.dump(self.store_path)
                    
    @staticmethod
    def do_work(threads):
        for thread in threads:
            thread.start()
        for thread in threads:
            thread.join()

# %%
store_path = "./stat.json"
morphs=['NOUN', 'ADJF', 'ADJS', 'COMP', 'VERB', 'INFN', 'PRTF', 'PRTS', 'GRND', 
        'NUMR', 'ADVB', 'NPRO', 'PRED', 'PREP', 'CONJ', 'PRCL', 'INTJ']
reader = WikiReader(
morphs=morphs, page_per_req=4, max_threads_per_daemon=8,
max_words=10000, store_every=1000, store_path=store_path
)
reader.run()
# Out:
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 884 of the file /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Exception in thread Thread-77:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-12-3ba09dad8cb6>", line 143, in thread_page_processing
#     self.word_processing(word, morph)
#   File "<ipython-input-12-3ba09dad8cb6>", line 153, in word_processing
#     self.dump(self.store_path)
#   File "<ipython-input-12-3ba09dad8cb6>", line 94, in dump
#     json.dump(cur_stats, file, indent=4, ensure_ascii=False)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py", line 179, in dump
#     for chunk in iterable:
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py", line 430, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py", line 404, in _iterencode_dict
#     yield from chunks
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py", line 356, in _iterencode_dict
#     for key, value in items:
# RuntimeError: dictionary changed size during iteration
#
# Exception in thread Thread-240:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-12-3ba09dad8cb6>", line 143, in thread_page_processing
#     self.word_processing(word, morph)
#   File "<ipython-input-12-3ba09dad8cb6>", line 153, in word_processing
#     self.dump(self.store_path)
#   File "<ipython-input-12-3ba09dad8cb6>", line 94, in dump
#     json.dump(cur_stats, file, indent=4, ensure_ascii=False)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py", line 179, in dump
#     for chunk in iterable:
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py", line 430, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py", line 404, in _iterencode_dict
#     yield from chunks
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py", line 356, in _iterencode_dict
#     for key, value in items:
# RuntimeError: dictionary changed size during iteration
#
# Exception in thread Thread-243:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-12-3ba09dad8cb6>", line 143, in thread_page_processing
#     self.word_processing(word, morph)
#   File "<ipython-input-12-3ba09dad8cb6>", line 153, in word_processing
#     self.dump(self.store_path)
#   File "<ipython-input-12-3ba09dad8cb6>", line 94, in dump
#     json.dump(cur_stats, file, indent=4, ensure_ascii=False)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py", line 179, in dump
#     for chunk in iterable:
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py", line 430, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py", line 404, in _iterencode_dict
#     yield from chunks
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py", line 356, in _iterencode_dict
#     for key, value in items:
# RuntimeError: dictionary changed size during iteration

# %%
a = 1
print(a)
# Out:
# 1

# %%
reader._stats
# Out:
# defaultdict(collections.Counter,
#             {'ADJF': Counter({'Сверхновая': 1,
#                       'сверхновых': 4,
#                       'которые': 9,
#                       'свою': 7,
#                       'катаклизмических': 1,
#                       'переменных': 1,
#                       'белого': 2,
#                       'Белый': 1,
#                       'которая': 8,
#                       'свой': 3,
#                       'нормальный': 1,
#                       'жизненный': 1,
#                       'которой': 8,
#                       'термоядерные': 1,
#                       'определённых': 1,
#                       'дальнейшие': 1,
#                       'углеродно-кислородного': 1,
#                       'огромное': 1,
#                       'своей': 4,
#                       'солнечных': 1,
#                       'максимальная': 1,
#                       'белый': 3,
#                       'другие': 4,
#                       'спиральная': 1,
#                       'всё': 1,
#                       'колумбийской': 1,
#                       'австралийской': 1,
#                       'который': 11,
#                       'животными': 1,
#                       'второй': 5,
#                       'общепринятой': 1,
#                       'Этот': 1,
#                       'перечисленных': 1,
#                       'оригинальной': 1,
#                       'общего': 4,
#                       'ядерного': 2,
#                       'своём': 1,
#                       'доступной': 1,
#                       'социальных': 1,
#                       'Новый': 7,
#                       'общий': 2,
#                       'английском': 1,
#                       'французском': 1,
#                       'оригинального': 1,
#                       'другой': 2,
#                       'всех': 6,
#                       'Боло́тная': 1,
#                       'ядерном': 1,
#                       'Центральном': 1,
#                       'административном': 1,
#                       'Алтайском': 1,
#                       'Песчаная': 1,
#                       'водного': 2,
#                       'государственного': 1,
#                       'Верхнеобскому': 1,
#                       'бассейновому': 1,
#                       'Фалеевского': 1,
#                       'Москворецкого': 2,
#                       'Водоотводный': 2,
#                       'Софийской': 1,
#                       'значительной': 2,
#                       'быстрая': 1,
#                       'термоядерная': 1,
#                       'классическая': 1,
#                       'алгебраической': 1,
#                       'непрерывная': 2,
#                       '-мерную': 1,
#                       '-мерное': 2,
#                       'евклидово': 2,
#                       'некоторой': 1,
#                       'противоположных': 1,
#                       'общее': 2,
#                       'достаточного': 1,
#                       'вызывающая': 1,
#                       'новой': 3,
#                       'сверхновой': 1,
#                       'Эта': 2,
#                       'одинаковой': 1,
#                       'максимальной': 1,
#                       'однородной': 1,
#                       'непрерывной': 3,
#                       '-мерном': 1,
#                       'евклидовом': 1,
#                       'Водоотводным': 1,
#                       'Болотной': 2,
#                       'водохозяйственный': 1,
#                       'этой': 6,
#                       'известных': 1,
#                       'Свой': 1,
#                       'теперешний': 1,
#                       'речной': 1,
#                       'Верхней': 1,
#                       'Речной': 1,
#                       'Верхняя': 1,
#                       'такие': 2,
#                       'противоположные': 1,
#                       'стандартных': 1,
#                       'н': 1,
#                       '«стандартная': 1,
#                       'астрономические': 1,
#                       'визуальная': 1,
#                       'звёздная': 1,
#                       'Ивановский': 1,
#                       'женский': 5,
#                       'котором': 3,
#                       'Эквивалентное': 1,
#                       'общем': 2,
#                       'нечётная': 1,
#                       'диаметральной': 1,
#                       '-мерной': 2,
#                       'римский': 1,
#                       'бывшем': 1,
#                       'Холмогорском': 1,
#                       'Первый': 5,
#                       'одной': 5,
#                       'Водоотводного': 1,
#                       'прежний': 2,
#                       'великопостного': 1,
#                       'Болотную': 1,
#                       'смертельного': 1,
#                       'Холмогорский': 1,
#                       'Пронский': 1,
#                       'польских': 1,
#                       'Покровский': 1,
#                       'нечётной': 2,
#                       'святой': 3,
#                       'римско-католической': 3,
#                       'католический': 1,
#                       'одномерном': 1,
#                       'промежуточном': 1,
#                       'алгебраико-топологический': 1,
#                       'комбинаторный': 1,
#                       'комбинаторным': 1,
#                       'Намюрский': 1,
#                       'Советским': 1,
#                       'произвольной': 1,
#                       'такая': 1,
#                       'Киевский': 1,
#                       'всея': 1,
#                       'первый': 8,
#                       'рязанский': 1,
#                       'муромский': 1,
#                       'Святых': 1,
#                       'исландский': 2,
#                       'китайский': 1,
#                       'придворный': 1,
#                       'равной': 2,
#                       'равным': 1,
#                       'фронтовой': 1,
#                       'Советского': 11,
#                       'одномерный': 1,
#                       'противоположными': 1,
#                       'историческое': 1,
#                       'Примечательные': 1,
#                       'чётной': 1,
#                       'дрессированной': 1,
#                       'двумерных': 1,
#                       'муниципального': 1,
#                       'Болотная': 3,
#                       '„Грибной': 1,
#                       'известного': 1,
#                       'Московские': 1,
#                       'Народный': 1,
#                       'нефтегазоно́сная': 1,
#                       'нефтегазоносная': 1,
#                       'Волынской': 1,
#                       'Западного': 1,
#                       'нефтегазоносного': 1,
#                       'Великомостовское': 1,
#                       'газовое': 2,
#                       'Локачинское': 1,
#                       'Шахтёрский': 1,
#                       'энциклопедический': 1,
#                       'Добровольческий': 1,
#                       'польская': 1,
#                       'добровольная': 1,
#                       'военизированная': 1,
#                       'польско-украинской': 1,
#                       'советско-польской': 1,
#                       'том': 10,
#                       'отдельный': 1,
#                       'добровольный': 1,
#                       'городской': 1,
#                       'Гражданской': 1,
#                       'административные': 1,
#                       'сторожевые': 1,
#                       'курьерские': 1,
#                       'вспомогательные': 1,
#                       'того': 6,
#                       'Турнирная': 1,
#                       'украинское': 1,
#                       'городское': 1,
#                       'женское': 2,
#                       'казарменное': 1,
#                       'официальное': 1,
#                       '«Добровольческий': 1,
#                       'бывшая': 1,
#                       'первым': 4,
#                       'женской': 1,
#                       'курьерской': 1,
#                       'своего': 4,
#                       'единственного': 1,
#                       'четырнадцатилетнего': 1,
#                       'погибшего': 1,
#                       'украинского': 1,
#                       'Лычаковском': 1,
#                       'польской': 1,
#                       'тому': 1,
#                       'спонтанное': 1,
#                       'самостоятельное': 1,
#                       'Буйвидувной': 1,
#                       'санитарной': 2,
#                       'польским': 1,
#                       'которых': 7,
#                       'польско-советской': 1,
#                       'танковых': 2,
#                       'интендантской': 1,
#                       'Мобилизационной': 1,
#                       'Добровольческого': 1,
#                       'женского': 1,
#                       'Главой': 1,
#                       'обособленная': 3,
#                       'все': 4,
#                       'статистическим': 1,
#                       'добровольческого': 1,
#                       'общую': 2,
#                       'квадратных': 1,
#                       'Омский': 1,
#                       'молодёжный': 1,
#                       'главного': 1,
#                       'сценическую': 1,
#                       'материальную': 1,
#                       'разножанровые': 1,
#                       'детскую': 1,
#                       'взрослую': 1,
#                       'водных': 1,
#                       'всей': 2,
#                       'позднее': 1,
#                       'первой': 8,
#                       'Польского': 1,
#                       'российских': 4,
#                       'международных': 3,
#                       'домашних': 2,
#                       'следующее': 1,
#                       'военизированное': 1,
#                       'Женская': 2,
#                       'военно-подготовительная': 1,
#                       'эти': 1,
#                       'военно-историческом': 1,
#                       '«Варшавская': 1,
#                       'жилых': 1,
#                       'Средняя': 1,
#                       'один': 1,
#                       'квадратный': 1,
#                       'Расовый': 2,
#                       'новыми': 1,
#                       'следующим': 2,
#                       'коренных': 2,
#                       'театральном': 2,
#                       'тихоокеанских': 1,
#                       'смешанных': 1,
#                       'других': 5,
#                       'обособленной': 4,
#                       'супружеские': 1,
#                       'одинокие': 1,
#                       'экспериментальный': 1,
#                       'открытый': 1,
#                       'окружающем': 1,
#                       'Средний': 6,
#                       'домашнего': 1,
#                       'средний': 6,
#                       'независимой': 2,
#                       'возрастному': 1,
#                       'качественные': 1,
#                       'каждые': 4,
#                       'международный': 2,
#                       'современного': 2,
#                       'самые': 1,
#                       'интересные': 1,
#                       'одно': 1,
#                       'домашнее': 1,
#                       'Первым': 2,
#                       'одну': 1,
#                       'среднегодового': 1,
#                       'новым': 1,
#                       'нестандартным': 1,
#                       'режиссерское': 1,
#                       'неожиданного': 1,
#                       'всем': 1,
#                       'именитые': 1,
#                       'Омского': 6,
#                       'долгое': 1,
#                       'актёрское': 2,
#                       'Лицейском': 1,
#                       'Лицейского': 1,
#                       'своим': 2,
#                       'гримёрную': 1,
#                       'балетный': 1,
#                       'художественного': 1,
#                       'зрительного': 1,
#                       'световая': 1,
#                       'косметический': 1,
#                       'разновозрастных': 1,
#                       'дополнительный': 1,
#                       'высшее': 1,
#                       '«Актёрское': 1,
#                       'драматический': 1,
#                       'Спонсорскую': 1,
#                       'профессиональные': 1,
#                       'сценическая': 1,
#                       'музыкально-педагогического': 1,
#                       'театральный': 10,
#                       'Всероссийский': 3,
#                       'молодёжных': 1,
#                       'высшей': 1,
#                       'германский': 3,
#                       '«Театральные': 1,
#                       'Европейской': 1,
#                       'зарубежному': 1,
#                       'официальные': 1,
#                       'Норчёпингской': 1,
#                       'морская': 1,
#                       '«крейсерская': 1,
#                       'особого': 7,
#                       'Императорского': 1,
#                       'Балтийского': 11,
#                       'транспортных': 1,
#                       'Германской': 1,
#                       'Балтийском': 3,
#                       'первые': 1,
#                       'Первой': 5,
#                       'мировой': 6,
#                       'советской': 2,
#                       'русского': 2,
#                       'Исторический': 1,
#                       'Нейтральная': 1,
#                       'Невским': 1,
#                       'военно-экономическое': 2,
#                       'германо-шведской': 1,
#                       'германской': 4,
#                       'Международном': 2,
#                       '«Русская': 2,
#                       'испанского': 1,
#                       'первую': 1,
#                       'стратегического': 2,
#                       'необходимого': 1,
#                       'военной': 3,
#                       'Морская': 1,
#                       'всю': 1,
#                       'самых': 3,
#                       'первых': 3,
#                       'импортных': 1,
#                       'Международный': 11,
#                       'омских': 1,
#                       'второе': 1,
#                       '«Молодильные': 2,
#                       'Всемирном': 1,
#                       'детских': 3,
#                       'нейтральной': 3,
#                       'шведской': 3,
#                       'железной': 6,
#                       'Балтийскому': 1,
#                       'бесперебойного': 1,
#                       'Торговые': 1,
#                       'балтийское': 1,
#                       'шведскими': 4,
#                       'русских': 3,
#                       'морских': 7,
#                       'современной': 4,
#                       'главной': 1,
#                       'шведского': 1,
#                       'лучших': 1,
#                       'сценических': 1,
#                       'Российской': 3,
#                       'полного': 1,
#                       'русским': 2,
#                       'народным': 1,
#                       'Международного': 5,
#                       'собственных': 2,
#                       'голубом': 3,
#                       '«Лучший': 5,
#                       'актерский': 2,
#                       'низким': 1,
#                       'остальная': 1,
#                       '«Золотая': 7,
#                       'этот': 3,
#                       'крупнейшем': 1,
#                       '«Рождественский': 1,
#                       'художественным': 1,
#                       'сам': 2,
#                       'крупнейшим': 2,
#                       'единственной': 1,
#                       'союзную': 1,
#                       'разумный': 1,
#                       'тех': 2,
#                       'профессиональный': 1,
#                       'значительные': 1,
#                       'германские': 2,
#                       'шведская': 1,
#                       'железная': 1,
#                       '«подводную': 1,
#                       'опасных': 1,
#                       'Балтийское': 2,
#                       'российской': 1,
#                       'военно-морской': 3,
#                       'германо-шведскую': 1,
#                       'торговых': 2,
#                       'германскими': 1,
#                       'норвежскими': 1,
#                       'Агентурные': 1,
#                       'Морским': 1,
#                       'специального': 1,
#                       'которому': 2,
#                       'шведский': 1,
#                       'германских': 4,
#                       'шведских': 2,
#                       'территориальных': 4,
#                       'германскому': 1,
#                       'германская': 1,
#                       'балтийская': 2,
#                       'ощутимый': 1,
#                       'эскортных': 3,
#                       'Второй': 1,
#                       'теми': 1,
#                       'юной': 1,
#                       'ценные': 1,
#                       'Восточно-Сибирскую': 1,
#                       'английских': 2,
#                       'драматического': 1,
#                       'сценической': 1,
#                       'её': 8,
#                       'дипломатических': 1,
#                       'российское': 2,
#                       'пластической': 1,
#                       '«ЧелоВЕК»им': 1,
#                       'таких': 3,
#                       'пластическая': 1,
#                       'своих': 2,
#                       'Восточного': 1,
#                       'Западный': 1,
#                       'эротической': 1,
#                       'Древнего': 1,
#                       'народная': 1,
#                       'Бурятском': 1,
#                       'боевые': 2,
#                       'позиционный': 1,
#                       'Балтийский': 1,
#                       'Первоочередные': 1,
#                       'такими': 1,
#                       'оборонительными': 1,
#                       'активные': 1,
#                       'возможного': 1,
#                       'музыкально-драматическая': 1,
#                       'Русском': 1,
#                       'драматическом': 2,
#                       'верховное': 1,
#                       'стратегическую': 1,
#                       'железорудных': 1,
#                       'никаких': 1,
#                       'Российским': 1,
#                       'подводным': 1,
#                       'высокую': 1,
#                       'Новосибирском': 1,
#                       '«Красный': 1,
#                       'торговым': 1,
#                       'театральная': 1,
#                       'Омском': 3,
#                       'немецкими': 1,
#                       'благоприятные': 1,
#                       'широкомасштабных': 1,
#                       '«Утиная': 1,
#                       'активных': 2,
#                       '«Прекрасный': 1,
#                       'второстепенных': 1,
#                       'Ярославском': 2,
#                       'общими': 1,
#                       'Многократный': 1,
#                       'пластических': 1,
#                       'сами': 1,
#                       'театрального': 1,
#                       'международного': 1,
#                       'Российского': 2,
#                       'многолетнюю': 1,
#                       'творческий': 1,
#                       'открытое': 1,
#                       'новых': 1,
#                       'ежегодной': 1,
#                       'латвийской': 1,
#                       'театральной': 1,
#                       'морской': 1,
#                       'мужской': 1,
#                       'лишний': 1,
#                       'нейтральную': 1,
#                       'недружественные': 1,
#                       'Германские': 1,
#                       'Германскому': 1,
#                       'Городской': 1,
#                       'оборонительные': 1,
#                       'энергичное': 1,
#                       'военно-морских': 1,
#                       'нашу': 1,
#                       'больших': 1,
#                       'одном': 1,
#                       'Теплицкий': 3,
#                       'мистическая': 1,
#                       'Мой': 1,
#                       'реальных': 1,
#                       'подводных': 4,
#                       'Ютландского': 1,
#                       'балтийскую': 1,
#                       'открытого': 1,
#                       'Обыкновенное': 1,
#                       'старая': 1,
#                       'ресторанный': 1,
#                       'плавучего': 1,
#                       'южный': 1,
#                       'Торговым': 1,
#                       'любимыми': 1,
#                       'национальной': 1,
#                       'артиллерийские': 1,
#                       'бракоразводный': 1,
#                       'торгового': 1,
#                       'корабельных': 1,
#                       'Каждая': 1,
#                       'вооружённых': 1,
#                       'этих': 1,
#                       'эффективным': 1,
#                       'подводной': 7,
#                       'надводных': 1,
#                       'вооружённые': 1,
#                       'весёлый': 1,
#                       'серьёзную': 1,
#                       'Служебный': 1,
#                       'музыкальное': 1,
#                       'любимого': 1,
#                       'практическое': 1,
#                       'всякую': 1,
#                       'крупной': 2,
#                       'Русская': 2,
#                       'Чудесный': 1,
#                       'комедия-ретро': 1,
#                       'светлое': 1,
#                       'Бременские': 1,
#                       'музыкальный': 1,
#                       'короткое': 1,
#                       'командующего': 2,
#                       'командующим': 1,
#                       'Каниным': 1,
#                       'Серый': 2,
#                       'северная': 1,
#                       'уважаемой': 1,
#                       'Рождественская': 1,
#                       'ночная': 2,
#                       'дозорных': 1,
#                       'сторожевых': 1,
#                       'Самый': 2,
#                       'жаркий': 1,
#                       'неприятельских': 1,
#                       'коммерческих': 1,
#                       'Молодильные': 1,
#                       'музыкальная': 1,
#                       'большим': 1,
#                       'такое': 1,
#                       'Игровая': 1,
#                       'Большая': 2,
#                       'механическая': 1,
#                       'новейших': 1,
#                       'флагманский': 1,
#                       'минной': 2,
#                       'лучшую': 6,
#                       'лучший': 1,
#                       'актёрский': 1,
#                       'мужскую': 1,
#                       'детского': 1,
#                       'независимого': 1,
#                       'эскадренных': 2,
#                       'Театральные': 1,
#                       'европейской': 2,
#                       '«Донской': 1,
#                       'корабельной': 1,
#                       'ударной': 1,
#                       'второго': 2,
#                       'специальный': 1,
#                       'юго-восточной': 1,
#                       'английские': 1,
#                       'подводные': 1,
#                       'российские': 1,
#                       'актерской': 2,
#                       'Або-Аландский': 1,
#                       'народной': 1,
#                       'материковой': 1,
#                       'южной': 1,
#                       'северной': 4,
#                       'означенного': 1,
#                       'встречных': 1,
#                       'детский': 3,
#                       'шведским': 1,
#                       'южном': 1,
#                       'нефтяных': 1,
#                       'следующих': 1,
#                       'театральных': 1,
#                       'основными': 1,
#                       'поисковые': 1,
#                       '«Театральная': 1,
#                       'юбилейной': 1,
#                       'культурной': 1,
#                       'Русско-Полянского': 1,
#                       'Омской': 1,
#                       'Омская': 2,
#                       'межрайонном': 1,
#                       'эстрадной': 1,
#                       'авторской': 1,
#                       'густого': 1,
#                       'Вечерний': 3,
#                       'Ваш': 1,
#                       'маневренного': 1,
#                       'финляндских': 1,
#                       'молодое': 1,
#                       'Театральная': 1,
#                       'омскую': 1,
#                       'Мобильная': 1,
#                       'лучшие': 1,
#                       'новом': 1,
#                       'международные': 1,
#                       'новый': 2,
#                       'первыми': 1,
#                       'французская': 1,
#                       'Официальный': 2,
#                       'установленное': 1,
#                       'радиоактивный': 1,
#                       'присутствующий': 1,
#                       'которое': 2,
#                       'Иная': 1,
#                       'твёрдого': 1,
#                       'кристаллическую': 2,
#                       'коллоидной': 1,
#                       'Химическая': 1,
#                       'Российская': 2,
#                       'светлого': 1,
#                       'французского': 1,
#                       'аперитивного': 1,
#                       'Все': 2,
#                       'цитрусовых': 1,
#                       'коктейльный': 1,
#                       'официальных': 1,
#                       'Международной': 4,
#                       'Оригинальный': 2,
#                       'одноимённом': 1,
#                       'прямом': 1,
#                       'Личный': 1,
#                       'двойного': 1,
#                       'любовной': 1,
#                       'вспомогательная': 1,
#                       'настоящий': 1,
#                       'разной': 1,
#                       'треугольной': 1,
#                       'натянутой': 1,
#                       'мелкоячеистой': 1,
#                       'таким': 1,
#                       'фигурному': 4,
#                       'юных': 1,
#                       'Международным': 1,
#                       'мужском': 1,
#                       'женском': 1,
#                       'одиночном': 1,
#                       'парном': 1,
#                       'фигурном': 1,
#                       'спортивных': 1,
#                       'возрастной': 2,
#                       'Окружным': 1,
#                       'западного': 1,
#                       'угольных': 1,
#                       'Соседние': 1,
#                       'верхний': 1,
#                       'Южный': 1,
#                       'Спортивный': 1,
#                       'текущий': 1,
#                       'следующие': 1,
#                       'одного': 2,
#                       'хелатное': 1,
#                       'Составная': 2,
#                       'экономико-статистический': 2,
#                       'каждой': 1,
#                       'Минимальная': 1,
#                       'техническая': 1,
#                       'Национальные': 1,
#                       'собранным': 1,
#                       'Национальным': 1,
#                       'средней': 1,
#                       'минимальной': 1,
#                       'технической': 1,
#                       'Медальный': 1,
#                       'Жирным': 1,
#                       'наибольшее': 1,
#                       'Спортивные': 1,
#                       'следующий': 1,
#                       'Валовой': 4,
#                       'внутренний': 4,
#                       'текущем': 2,
#                       'Бразильский': 4,
#                       'человеческого': 2,
#                       'зимние': 3,
#                       'юношеские': 3,
#                       'Олимпийские': 3,
#                       'Данный': 1,
#                       'Эти': 1,
#                       'нормальных': 1,
#                       'пурпурно-красные': 2,
#                       'кислой': 1,
#                       'следующего': 2,
#                       'Интересные': 2,
#                       'китайском': 1,
#                       'официальном': 1,
#                       'Неорганическая': 1,
#                       'Никольский': 2,
#                       'супружеских': 1,
#                       'отдельных': 1,
#                       'одиноких': 1,
#                       'Известные': 1,
#                       'танковый': 1,
#                       'компьютерных': 1,
#                       'основные': 1,
#                       'Игровой': 1,
#                       'боевого': 1,
#                       'превосходящих': 1,
#                       'Варшавского': 1,
#                       'большей': 1,
#                       'положительную': 1,
#                       'белорусской': 1,
#                       'Ланской': 1,
#                       'легендарной': 1,
#                       '3-хлетний': 1,
#                       'Национального': 1,
#                       'отборочного': 1,
#                       'высший': 1,
#                       'профессионального': 2,
#                       'новую': 1,
#                       'болгарский': 1,
#                       'родном': 1,
#                       'изобразительных': 1,
#                       'международном': 1,
#                       'Лучшая': 1,
#                       'австрийского': 1,
#                       'эта': 1,
#                       'римская': 1,
#                       'Национальная': 1,
#                       'одним': 2,
#                       'центральных': 1,
#                       'большое': 1,
#                       'стилистическими': 1,
#                       'мирская': 1,
#                       'сама': 1,
#                       'похожее': 1,
#                       'пассивная': 1,
#                       'орнаментальный': 1,
#                       '«Ночной': 1,
#                       'самым': 1,
#                       'латвийская': 1,
#                       'Латвийской': 2,
#                       'Латвийскую': 1,
#                       'Персональные': 1,
#                       'натуралистическим': 1,
#                       'символический': 1,
#                       'первая': 1,
#                       'своё': 2,
#                       'бесконечные': 1,
#                       'последняя': 1,
#                       'неизменное': 1,
#                       'многочисленные': 1,
#                       'фаллический': 1,
#                       'государственной': 1,
#                       'Лесном': 1,
#                       'памятная': 2,
#                       'золотая': 2,
#                       'Кавказских': 1,
#                       'советский': 4,
#                       'мемориальная': 1,
#                       'позднего': 1,
#                       'Наибольшее': 1,
#                       'Твоя': 2,
#                       'рижском': 1,
#                       'Святой': 1,
#                       'немецких': 1,
#                       'Латвийский': 1,
#                       'культурный': 1,
#                       '«Серебряная': 1,
#                       'вторая': 1,
#                       'симфонические': 1,
#                       'симфоническая': 1,
#                       'Камерная': 1,
#                       'народных': 1,
#                       'женских': 1,
#                       'ежегодный': 1,
#                       'профессиональных': 1,
#                       'Маломихайловский': 1,
#                       'сельский': 1,
#                       'Криничанского': 1,
#                       'Днепропетровской': 1,
#                       'Административный': 1,
#                       'сельского': 4,
#                       'староместском': 1,
#                       'Королевском': 1,
#                       'Одна': 1,
#                       'чешской': 1,
#                       'которого': 1,
#                       'сводчатая': 1,
#                       'староместский': 1,
#                       'мостовой': 3,
#                       'красной': 2,
#                       'Святая': 1,
#                       'Чешская': 1,
#                       'Святого': 3,
#                       'бездомным': 1,
#                       'престарелыми': 1,
#                       'больными': 1,
#                       'самостоятельного': 1,
#                       'духовного': 1,
#                       'госпитального': 1,
#                       'чешский': 1,
#                       'красному': 1,
#                       'шестиконечная': 1,
#                       'такого': 1,
#                       'Современный': 1,
#                       'высокой': 1,
#                       'художественной': 1,
#                       'каждого': 1,
#                       'барокко': 1,
#                       'Ассизского': 1,
#                       'соседнего': 1,
#                       'бывшего': 1,
#                       'Узкая': 1,
#                       'пониженный': 1,
#                       'Восточная': 1,
#                       'пражского': 1,
#                       'восточной': 2,
#                       'важный': 1,
#                       'транспортный': 1,
#                       'трамвайная': 1,
#                       'автомобильная': 1,
#                       'Староместская': 1,
#                       'мостовая': 1,
#                       'неоготический': 1,
#                       'дрезденского': 1,
#                       'венгерских': 1,
#                       'танковой': 1,
#                       'танкового': 1,
#                       'гвардейской': 2,
#                       'Южной': 1,
#                       'советских': 1,
#                       'нюрнбергским': 1,
#                       'студенческих': 1,
#                       'Славянского': 1,
#                       'Шортандинском': 1,
#                       'Акмолинской': 1,
#                       'Виноградарский': 1,
#                       'Винный': 1,
#                       'виноградной': 1,
#                       'собственными': 1,
#                       'Барочный': 1,
#                       'Клинского': 4,
#                       'Московской': 3,
#                       'северо-восточную': 1,
#                       'сторожевой': 1,
#                       'двухэтажный': 1,
#                       'бывший': 1,
#                       'городских': 1,
#                       'Русский': 1,
#                       'Советской': 1,
#                       'Действительную': 1,
#                       'военную': 2,
#                       'Отдельной': 1,
#                       'дислоцированной': 1,
#                       'коронационному': 1,
#                       'мотострелковой': 1,
#                       'контрреволюционного': 1,
#                       'Венгерское': 1,
#                       'Верховного': 2,
#                       'воинского': 1,
#                       'остальные': 1,
#                       'Калининском': 1,
#                       'железобетонных': 1,
#                       'среднюю': 2,
#                       'рабочей': 1,
#                       'Всесоюзный': 1,
#                       'заочный': 1,
#                       'политехнический': 1,
#                       'внутренних': 1,
#                       'Федеральном': 1,
#                       'мемориальном': 1,
#                       'Краткий': 1,
#                       'биографический': 1,
#                       'Шкадов': 1,
#                       'Западная': 1,
#                       'отделенный': 1,
#                       'центральной': 1,
#                       'дебютный': 1,
#                       'студийный': 1,
#                       'британской': 1,
#                       'американский': 1,
#                       'баскетбольный': 1,
#                       'первоначальным': 1,
#                       'железнодорожного': 1,
#                       'бесплатный': 1,
#                       'автобусный': 1,
#                       'бесплатных': 1,
#                       'открытых': 1,
#                       'крытых': 1,
#                       'железнодорожный': 1,
#                       'хоккейный': 1,
#                       'Национальной': 3,
#                       'баскетбольной': 3,
#                       'самого': 1,
#                       'Баскетбольного': 1,
#                       'существующая': 1,
#                       '«Шотландский': 1,
#                       'еврейской': 1,
#                       'Кропивницкий': 1,
#                       '«Пресвитерианская': 1,
#                       'греческой': 1,
#                       'македонской': 1,
#                       'своими': 2,
#                       'неофициальными': 1,
#                       'Йельский': 1,
#                       'юридическое': 1,
#                       'выдающимся': 2,
#                       'важную': 1,
#                       'отдельным': 1,
#                       'Американской': 1,
#                       'хоккейной': 1,
#                       'новообразованной': 1,
#                       'Баскетбольной': 1,
#                       'широкий': 1,
#                       'азиатской': 1,
#                       'средиземноморской': 1,
#                       'ночной': 1,
#                       'профессиональными': 1,
#                       'неофициальный': 1,
#                       'Национальную': 1,
#                       'баскетбольную': 1,
#                       'ключевым': 1,
#                       'непростые': 1,
#                       'университетский': 1,
#                       'телевизионный': 1,
#                       'договорные': 1,
#                       'одна': 1,
#                       'ценный': 1,
#                       'регулярного': 1,
#                       'кировоградской': 1,
#                       'дворянский': 1,
#                       'Титулярные': 1,
#                       'последний': 1,
#                       'потомственное': 1,
#                       'дворянское': 1,
#                       'четырёхчастный': 1,
#                       'золотой': 3,
#                       'червлёные': 1,
#                       'лазоревой': 1,
#                       'серебряный': 1,
#                       'червлёными': 1,
#                       'третьей': 1,
#                       'зелёной': 1,
#                       'такою': 1,
#                       'круглою': 1,
#                       'четвёртой': 1,
#                       'серебряной': 1,
#                       'зелёный': 1,
#                       'лавровый': 1,
#                       'золотою': 1,
#                       'дворянскими': 1,
#                       'серебряных': 1,
#                       'страусовых': 1,
#                       'червлёный': 1,
#                       'лазоревый': 1,
#                       'Общего': 2,
#                       'дворянских': 2,
#                       'Всероссийской': 2,
#                       'Российский': 1,
#                       'литературных': 2,
#                       'Пермской': 1,
#                       'Ижевского': 1,
#                       'механического': 1,
#                       'Дронговский': 6,
#                       'польский': 1,
#                       'Клубная': 2,
#                       'Свою': 1,
#                       'футбольную': 1,
#                       'юниорской': 1,
#                       'белостокского': 1,
#                       'каждый': 1,
#                       'детской': 2,
#                       '«Серебряный': 2,
#                       'молодёжной': 3,
#                       'которую': 2,
#                       'Третьей': 1,
#                       'русском': 1,
#                       'татарских': 1,
#                       'постоянным': 1,
#                       'вроцлавского': 1,
#                       'тот': 1,
#                       'основной': 2,
#                       ...}),
#              'ADJS': Counter({'«Чертова': 1,
#                       'Беллино': 1,
#                       'Бенни': 1,
#                       'Боженова': 1,
#                       'Бонобо': 1,
#                       'Гаштала': 1,
#                       'Голы': 1,
#                       'Зефиров': 1,
#                       'Корто': 1,
#                       'Кучково': 1,
#                       'Похоронен': 2,
#                       'Пьянова': 2,
#                       'Служил': 1,
#                       'Таксино': 3,
#                       'Трухачёва': 2,
#                       'Шмаково': 1,
#                       'басист': 1,
#                       'возможны': 1,
#                       'вынужден': 1,
#                       'готово': 1,
#                       'должен': 3,
#                       'должна': 1,
#                       'должны': 4,
#                       'известен': 1,
#                       'изоморфны': 1,
#                       'нафтогазоносна': 1,
#                       'неизвестна': 2,
#                       'необходим': 2,
#                       'ограничен': 1,
#                       'открыт': 5,
#                       'переросло': 1,
#                       'показва': 1,
#                       'применимо': 1,
#                       'равен': 1,
#                       'рады': 1,
#                       'рус': 1,
#                       'служил': 4,
#                       'слышны': 1,
#                       'стоял': 2,
#                       'удалён': 1,
#                       'фигуриста': 1}),
#              'ADVB': Counter({'«Только': 1,
#                       'Банско': 2,
#                       'Более': 1,
#                       'Вдоль': 1,
#                       'Впервые': 2,
#                       'Всего': 1,
#                       'Вскоре': 2,
#                       'Ещё': 2,
#                       'Затем': 2,
#                       'Иногда': 1,
#                       'Невозможно': 1,
#                       'Неформально': 1,
#                       'Округ': 1,
#                       'Официально': 1,
#                       'Постепенно': 1,
#                       'Поэтому': 1,
#                       'Статистически': 1,
#                       'Физически': 1,
#                       'Формально': 1,
#                       'активно': 1,
#                       'более': 6,
#                       'вдоль': 3,
#                       'весьма': 1,
#                       'взамен': 1,
#                       'влево': 1,
#                       'вместе': 4,
#                       'вновь': 1,
#                       'вокруг': 1,
#                       'впервые': 4,
#                       'вплоть': 1,
#                       'всегда': 1,
#                       'всего': 5,
#                       'вскоре': 2,
#                       'высоко': 2,
#                       'гармонично': 1,
#                       'где': 16,
#                       'годами': 1,
#                       'действительно': 1,
#                       'диаметрально': 3,
#                       'домой': 1,
#                       'дорогой': 1,
#                       'достаточно': 1,
#                       'ещё': 3,
#                       'заранее': 1,
#                       'затем': 3,
#                       'зачастую': 1,
#                       'здесь': 2,
#                       'изначально': 1,
#                       'красиво': 1,
#                       'менее': 2,
#                       'много': 3,
#                       'наравне': 1,
#                       'настолько': 1,
#                       'невозможно': 1,
#                       'недалеко': 1,
#                       'неизвестно': 1,
#                       'неоднократно': 2,
#                       'непосредственно': 1,
#                       'несколько': 7,
#                       'нормално': 1,
#                       'ныне': 5,
#                       'обычно': 3,
#                       'обязательно': 1,
#                       'одновременно': 1,
#                       'округ': 2,
#                       'особенно': 1,
#                       'оттуда': 1,
#                       'официально': 3,
#                       'параллельно': 1,
#                       'первоначально': 2,
#                       'пешком': 1,
#                       'пожизненно': 1,
#                       'пока': 1,
#                       'попутно': 1,
#                       'постепенно': 1,
#                       'постоянно': 1,
#                       'потому': 1,
#                       'почти': 1,
#                       'поэтому': 1,
#                       'прежде': 3,
#                       'преимущественно': 1,
#                       'примерно': 2,
#                       'прочно': 1,
#                       'ранее': 2,
#                       'самовольно': 1,
#                       'самостоятельно': 2,
#                       'свыше': 1,
#                       'сейчас': 1,
#                       'сиквеле': 1,
#                       'сильно': 2,
#                       'слева': 1,
#                       'сначала': 1,
#                       'снова': 1,
#                       'совершенно': 1,
#                       'совместно': 3,
#                       'специально': 1,
#                       'справа': 1,
#                       'справедливо': 1,
#                       'статистически': 6,
#                       'строго': 1,
#                       'сугубо': 1,
#                       'существенно': 1,
#                       'там': 2,
#                       'уже': 3,
#                       'часами': 1,
#                       'часто': 1,
#                       'частью': 5,
#                       'чего-то': 1,
#                       'эмпирически': 1}),
#              'COMP': Counter({'легче': 1,
#                       'меньше': 1,
#                       'младше': 1,
#                       'моложе': 2,
#                       'позже': 1,
#                       'сильнее': 1,
#                       'старше': 9}),
#              'CONJ': Counter({'А': 3,
#                       'Али': 1,
#                       'Если': 2,
#                       'Как': 4,
#                       'Когда': 1,
#                       'Кстати': 1,
#                       'Но': 3,
#                       'Однако': 1,
#                       'Так': 1,
#                       'Также': 2,
#                       'Тем': 2,
#                       'Хотя': 1,
#                       'Что': 1,
#                       'а': 20,
#                       'возможно': 1,
#                       'если': 2,
#                       'и': 297,
#                       'или': 16,
#                       'как': 24,
#                       'когда': 6,
#                       'либо': 1,
#                       'но': 13,
#                       'однако': 1,
#                       'поскольку': 1,
#                       'причём': 1,
#                       'так': 9,
#                       'также': 15,
#                       'тем': 4,
#                       'то': 10,
#                       'хотя': 2,
#                       'чем': 1,
#                       'что': 30,
#                       'чтобы': 2}),
#              'GRND': Counter({'«Моя': 1,
#                       'Будучи': 1,
#                       'Вернувшись': 1,
#                       'Корпоратив': 1,
#                       'Опасаясь': 1,
#                       'Получив': 1,
#                       'Устав': 1,
#                       'вернувшись': 1,
#                       'возвещая': 1,
#                       'войдя': 1,
#                       'выступая': 1,
#                       'выходя': 1,
#                       'дав': 1,
#                       'обеспечивая': 1,
#                       'образуя': 1,
#                       'опасаясь': 1,
#                       'переведя': 1,
#                       'поднимая': 1,
#                       'получив': 1,
#                       'помышляя': 1,
#                       'разбив': 1,
#                       'разделившись': 1,
#                       'сосредоточенв': 1,
#                       'сохранив': 1,
#                       'став': 1,
#                       'суша': 1,
#                       'сформировав': 1,
#                       'сыграв': 1,
#                       'являясь': 1}),
#              'INFN': Counter({'«произвести': 1,
#                       'Попробовать': 1,
#                       'быть': 4,
#                       'вернуть': 1,
#                       'воевать': 2,
#                       'возвестить': 1,
#                       'встать': 1,
#                       'вывести': 1,
#                       'выйти': 4,
#                       'выставить': 3,
#                       'добраться': 1,
#                       'допустить': 1,
#                       'достичь': 1,
#                       'достраивать': 1,
#                       'дотянуться': 1,
#                       'закрашивать': 1,
#                       'идти': 1,
#                       'избежать': 2,
#                       'иметь': 2,
#                       'использоваться': 1,
#                       'коллапсировать': 1,
#                       'мириться': 1,
#                       'найти': 1,
#                       'объединить': 1,
#                       'оградить': 1,
#                       'остановить': 1,
#                       'отдавать': 1,
#                       'отойти': 1,
#                       'повернуть': 1,
#                       'повысить': 1,
#                       'поддерживать': 1,
#                       'подставить': 1,
#                       'познакомиться': 1,
#                       'попасть': 1,
#                       'пополняться': 1,
#                       'поработать': 1,
# ...
#                       'Веспер': 3,
#                       'Виттек': 1,
#                       'Возглавлял': 1,
#                       'Входит': 5,
#                       'Выбирай': 1,
#                       'Дали': 1,
#                       'Замерзли': 1,
#                       'Занимает': 3,
#                       'Занимал': 1,
#                       'Изложба-акварел': 1,
#                       'Используется': 1,
#                       'Классифицируется': 1,
#                       'Мацуреву': 1,
#                       'Митчел-фривей': 1,
#                       'Молились': 1,
#                       'Начало': 1,
#                       'Окончил': 1,
#                       'Окончила': 1,
#                       'Паудерли': 1,
#                       'Покорили': 1,
#                       'Поступил': 1,
#                       'Продолжила': 1,
#                       'Проживал': 1,
#                       'Проходит': 1,
#                       'Работал': 3,
#                       'Родилась': 1,
#                       'Родился': 5,
#                       'Руководил': 1,
#                       'Селби': 1,
#                       'Скончался': 1,
#                       'Состоит': 1,
#                       'Умер': 1,
#                       'Уорли': 1,
#                       'Четяну': 1,
#                       'Эверли': 1,
#                       'Являлся': 1,
#                       'адсорбируются': 1,
#                       'атрибутировал': 1,
#                       'берёт': 1,
#                       'будет': 2,
#                       'будут': 4,
#                       'был': 28,
#                       'была': 18,
#                       'были': 22,
#                       'было': 15,
#                       'ввела': 1,
#                       'ввёл': 2,
#                       'вдохновил': 1,
#                       'ведётся': 1,
#                       'велась': 1,
#                       'вернусь': 1,
#                       'верят': 1,
#                       'взбунтовалось': 1,
#                       'взрываются': 1,
#                       'включает': 1,
#                       'возвращались': 1,
#                       'возвращаются': 1,
#                       'возникла': 1,
#                       'вознёсся': 1,
#                       'возрастало': 1,
#                       'воспитывали': 1,
#                       'вошли': 1,
#                       'вошёл': 1,
#                       'встречается': 1,
#                       'входило': 1,
#                       'входит': 6,
#                       'входят': 1,
#                       'выбирают': 1,
#                       'выводится': 1,
#                       'выдвигает': 1,
#                       'выделило': 1,
#                       'выделяются': 1,
#                       'выезжает': 2,
#                       'выезжают': 1,
#                       'вынеси': 1,
#                       'выполняли': 1,
#                       'выпустила': 1,
#                       'выразил': 1,
#                       'вырос': 1,
#                       'выросла': 1,
#                       'высвобождают': 1,
#                       'выступает': 1,
#                       'выступал': 3,
#                       'выступали': 1,
#                       'выступили': 1,
#                       'выходила': 1,
#                       'выходили': 1,
#                       'выходит': 1,
#                       'вышел': 1,
#                       'гласит': 1,
#                       'давал': 2,
#                       'давала': 1,
#                       'давало': 1,
#                       'дала': 1,
#                       'дало': 1,
#                       'дебютировал': 2,
#                       'дебютировала': 1,
#                       'делал': 1,
#                       'добавилась': 1,
#                       'добилась': 1,
#                       'договорился': 1,
#                       'докладывала': 1,
#                       'достиг': 1,
#                       'достигнет': 1,
#                       'душу': 4,
#                       'ездил': 1,
#                       'ждёт': 1,
#                       'живеят': 1,
#                       'живут': 1,
#                       'живёт': 1,
#                       'жила': 2,
#                       'жили': 1,
#                       'забил': 1,
#                       'завершил': 1,
#                       'завершила': 1,
#                       'зависит': 1,
#                       'завоевал': 1,
#                       'заключил': 1,
#                       'закончил': 1,
#                       'закончила': 1,
#                       'закончили': 1,
#                       'заладилось': 1,
#                       'замахнется': 1,
#                       'занимает': 3,
#                       'занимается': 1,
#                       'занимаются': 1,
#                       'занял': 2,
#                       'заняли': 1,
#                       'западу': 1,
#                       'записывала': 1,
#                       'заразился': 1,
#                       'заселяли': 1,
#                       'заслужил': 1,
#                       'заставляет': 1,
#                       'защитил': 1,
#                       'звучит': 1,
#                       'знает': 3,
#                       'играл': 1,
#                       'играют': 1,
#                       'идет': 1,
#                       'изключителни': 1,
#                       'иллюстрируют': 1,
#                       'имеет': 6,
#                       'имеется': 2,
#                       'имели': 3,
#                       'имелось': 1,
#                       'имеют': 3,
#                       'исполнил': 1,
#                       'исполнила': 1,
#                       'исполняет': 1,
#                       'использовалась': 1,
#                       'использует': 1,
#                       'испытали': 1,
#                       'испытывала': 1,
#                       'лежит': 2,
#                       'любишь': 1,
#                       'могли': 3,
#                       'могут': 3,
#                       'может': 3,
#                       'называет': 1,
#                       'найдутся': 1,
#                       'найдётся': 1,
#                       'написал': 1,
#                       'написала': 2,
#                       'написали': 1,
#                       'направился': 1,
#                       'насчитывается': 1,
#                       'насчитывал': 1,
#                       'насчитывало': 1,
#                       'насчитывалось': 1,
#                       'находились': 1,
#                       'находилось': 1,
#                       'находится': 4,
#                       'находятся': 1,
#                       'начал': 3,
#                       'начали': 1,
#                       'начало': 1,
#                       'началось': 1,
#                       'начнет': 1,
#                       'начнёт': 1,
#                       'несёт': 1,
#                       'носили': 1,
#                       'обвязывались': 1,
#                       'обеспечивал': 2,
#                       'обладает': 1,
#                       'образовалась': 1,
#                       'образует': 2,
#                       'образуют': 1,
#                       'обратилась': 1,
#                       'обращается': 1,
#                       'обслуживало': 1,
#                       'обучались': 1,
#                       'объединяет': 1,
#                       'оказал': 1,
#                       'оказались': 1,
#                       'оказался': 1,
#                       'оказывает': 1,
#                       'оказывается': 1,
#                       'окончил': 7,
#                       'окончила': 1,
#                       'описывает': 1,
#                       'опускают': 1,
#                       'организовали': 1,
#                       'основал': 1,
#                       'основала': 1,
#                       'осознавало': 1,
#                       'оставил': 1,
#                       'осталась': 1,
#                       'отвечала': 1,
#                       'отказалась': 1,
#                       'открывает': 1,
#                       'относится': 2,
#                       'отправлялись': 1,
#                       'отсеялась': 1,
#                       'отстранил': 1,
#                       'оценило': 1,
#                       'перевели': 1,
#                       'перевело': 1,
#                       'перевёл': 1,
#                       'передавали': 1,
#                       'переехал': 3,
#                       'переключилась': 1,
#                       'перенесла': 1,
#                       'перестал': 1,
#                       'перешёл': 1,
#                       'писал': 3,
#                       'планировала': 1,
#                       'планировались': 1,
#                       'победила': 1,
#                       'погиб': 1,
#                       'погибли': 1,
#                       'подводят': 1,
#                       'подготовила': 1,
#                       'поднимается': 1,
#                       'подписал': 2,
#                       'позволило': 1,
#                       'позволяет': 1,
#                       'позиционировалась': 1,
#                       'показала': 1,
#                       'покинул': 1,
#                       'покритиковала': 1,
#                       'получают': 1,
#                       'получил': 5,
#                       'получила': 2,
#                       'получили': 1,
#                       'получило': 1,
#                       'поменяла': 1,
#                       'помог': 2,
#                       'понравился': 1,
#                       'последуют': 1,
#                       'поставил': 1,
#                       'поставила': 1,
#                       'поставлялась': 1,
#                       'поступил': 3,
#                       'поступила': 1,
#                       'поступили': 1,
#                       'потеряла': 1,
#                       'предоставляет': 1,
#                       'предписывалось': 3,
#                       'представил': 1,
#                       'представляет': 2,
#                       'представляли': 1,
#                       'представляют': 1,
#                       'предстоит': 1,
#                       'предстояло': 1,
#                       'прекратились': 1,
#                       'прекращались': 1,
#                       'преподавал': 1,
#                       'преподавала': 1,
#                       'привели': 1,
#                       'привлекла': 1,
#                       'привнесут': 1,
#                       'приглашался': 1,
#                       'приглашают': 1,
#                       'применяется': 1,
#                       'принадлежит': 2,
#                       'принимает': 3,
#                       'принимал': 3,
#                       'принимали': 1,
#                       'принял': 2,
#                       'приняли': 1,
#                       'приняло': 1,
#                       'приобрела': 3,
#                       'приобретает': 1,
#                       'присоединилась': 1,
#                       'приступил': 1,
#                       'присудило': 1,
#                       'приходил': 1,
#                       'приходила': 1,
#                       'приходилось': 2,
#                       'приходится': 1,
#                       'провёл': 4,
#                       'продолжил': 1,
#                       'проживает': 2,
#                       'проживали': 2,
#                       'проживало': 1,
#                       'проживают': 1,
#                       'прозвучала': 1,
#                       'производят': 1,
#                       'происходит': 1,
#                       'происходят': 1,
#                       'прославились': 1,
#                       'протекает': 1,
#                       'протекал': 1,
#                       'проходил': 2,
#                       'проходит': 1,
#                       'прошла': 1,
#                       'прошли': 2,
#                       'прошёл': 1,
#                       'публиковались': 1,
#                       'работает': 2,
#                       'работал': 3,
#                       'работала': 1,
#                       'разворачивались': 1,
#                       'разрабатывает': 1,
#                       'разыгрывались': 1,
#                       'разыскал': 1,
#                       'располагала': 1,
#                       'располагался': 1,
#                       'распределилось': 1,
#                       'распределился': 1,
#                       'распространялся': 1,
#                       'рассказывает': 1,
#                       'рассматривались': 1,
#                       'расставайтесь': 1,
#                       'расширил': 1,
#                       'расширило': 1,
#                       'рекомендовалось': 1,
#                       'реконструировал': 1,
#                       'решил': 2,
#                       'родилась': 1,
#                       'родились': 1,
#                       'родился': 1,
#                       'руководил': 1,
#                       'рукоплескала': 1,
#                       'свидетельствовали': 1,
#                       'село': 3,
#                       'символизирует': 1,
#                       'славится': 1,
#                       'следует': 1,
#                       'сливается': 1,
#                       'служили': 1,
#                       'сменил': 1,
#                       'смешиваются': 1,
#                       'смогли': 1,
#                       'сможет': 1,
#                       'снимается': 1,
#                       'снискала': 1,
#                       'снялась': 1,
#                       'снялись': 1,
#                       'содержит': 1,
#                       'создавало': 1,
#                       'создали': 2,
#                       'сообщило': 1,
#                       'сорбируется': 1,
#                       'составил': 4,
#                       'составили': 2,
#                       'составляет': 15,
#                       'составляла': 1,
#                       'составляло': 2,
#                       'составляют': 2,
#                       'состоит': 1,
#                       'состояла': 1,
#                       'состоялась': 1,
#                       'состоялось': 1,
#                       'состоялся': 2,
#                       'состоят': 1,
#                       'состоятся': 1,
#                       'сотрудничает': 1,
#                       'сохранилось': 1,
#                       'сохраняются': 1,
#                       'сочетаются': 1,
#                       'сошёл': 1,
#                       'ставил': 1,
#                       'ставились': 2,
#                       'ставим': 1,
#                       'стал': 7,
#                       'стала': 6,
#                       'стали': 2,
#                       'стало': 2,
#                       'становится': 1,
#                       'старались': 1,
#                       'старалось': 1,
#                       'стоит': 1,
#                       'сузила': 1,
#                       'существовало': 1,
#                       'существует': 1,
#                       'существуют': 1,
#                       'сформировало': 1,
#                       'сцеживают': 1,
#                       'считается': 2,
#                       'считалась': 1,
#                       'считали': 1,
#                       'считаются': 1,
#                       'сыграл': 2,
#                       'требует': 1,
#                       'увидят': 1,
#                       'удовлетворил': 1,
#                       'удовлетворяла': 1,
#                       'умеет': 1,
#                       'умер': 1,
#                       'уничтожил': 1,
#                       'упала': 1,
#                       'усилила': 1,
#                       'усмотрела': 1,
#                       'устанавливается': 1,
#                       'устраивали': 1,
#                       'утверждала': 1,
#                       'ухаживал': 1,
#                       'ухожу': 2,
#                       'участвовал': 4,
#                       'участвовали': 1,
#                       'участвует': 1,
#                       'училась': 1,
#                       'фигурирует': 1,
#                       'фильтруют': 1,
#                       'формирует': 1,
#                       'хотим': 1,
#                       'хотят': 1,
#                       'шёл': 1,
#                       'экспонировались': 1,
#                       'эмигрировала': 1,
#                       'является': 6,
#                       'являлась': 1,
#                       'являлся': 1,
#                       'являются': 1})})
